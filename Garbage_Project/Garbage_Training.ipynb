# %% [markdown]
# # Mask R-CNN Training and Inference
# In this notebook we use Matterport's implementation of Mask R-CNN to train on a custom dataset, then use the trained weights to run inference on new images.
#
# This is part of a tutorial posted at http://www.immersivelimit.com/tutorials/using-mask-r-cnn-on-custom-coco-like-dataset, so check there for more details.
#
# ### Not a beginner tutorial...
# This is not intended to be a complete beginner tutorial.
# - You should know how to clone a git repository from GitHub
# - You should have a decent understanding of Python programming
# - You should understand the basics of training deep neural networks. If you've never done it before, I wouldn't recommend starting here. Find a beginner deep learning tutorial/course and start there. There's lots of great free stuff on YouTube.
#
# ## **Download the Free Training Dataset First!
# I've provided a free training dataset of cigarette butt images for use with this tutorial.
# 1. Download it from here: http://www.immersivelimit.com/datasets/cigarette-butts
# 2. Then extract the files and put it in the "../datasets" directory of this repo
# 3. The code below will be looking for "../datasets/cig_butts/train", "../datasets/cig_butts/val", and "../datasets/cig_butts/real_test"

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 703016508796243921, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 6124225328970304068
#  physical_device_desc: "device: XLA_CPU device"]

# %%
import os
import sys
import json
import numpy as np
import time
from PIL import Image, ImageDraw
import pathlib
import random
import shutil

# %% [markdown]
# ## Import Matterport's "mrcnn" libraries
# 1. I'm using a forked version of Matterport's Mask_RCNN git repo to make sure this code works, even if the main repo changes. As of July 29, 2018, there is a bug in Matterport's version that breaks loading an existing model that I've fixed in my version (and submitted a pull request to fix it in theirs).
#   - My version is here: https://github.com/akTwelve/Mask_RCNN
#   - The original is here: https://github.com/matterport/Mask_RCNN
# 2. Update the code cell below to point to the root directory of the repo on your machine.

# %%
# Set the ROOT_DIR variable to the root directory of the Mask_RCNN git repo
ROOT_DIR = '../../aktwelve_mask_rcnn'
assert os.path.exists(ROOT_DIR), 'ROOT_DIR does not exist. Did you forget to read the instructions above? ;)'

# Import mrcnn libraries
sys.path.append(ROOT_DIR) 
from mrcnn.config import Config
import mrcnn.utils as utils
from mrcnn import visualize
import mrcnn.model as modellib
import skimage

# %% [markdown]
# ## Set up logging and pre-trained model paths
# This will default to sub-directories in your mask_rcnn_dir, but if you want them somewhere else, updated it here.
#
# It will also download the pre-trained coco model.

# %%
# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "g_logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")

# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)

# %% [markdown]
# ## Configuration
# Define configurations for training on the Cigarette Butt dataset.
# ### Note
# These are settings that worked on my machine (GTX 970 graphics card). If you are getting OOM (Out of Memory) errors, you may need to tweak the settings or your computer may not be powerful enough. If you have a better graphics card, you will want to tweak it to take advantage of that.

# %%
class GomiConfig(Config):
    """Configuration for training on the cigarette butts dataset.
    Derives from the base Config class and overrides values specific
    to the cigarette butts dataset.
    """
    # Give the configuration a recognizable name
    NAME = "gomi"

    # Train on 1 GPU and 1 image per GPU. Batch size is 1 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

    # Number of classes (including background)
    NUM_CLASSES = 1 + 7  # background + 1 (cig_butt)

    # All of our training images are 512x512
    IMAGE_MIN_DIM = 512
    IMAGE_MAX_DIM = 512

    # You can experiment with this number to see if it improves training
    STEPS_PER_EPOCH = 50

    # This is how often validation is run. If you are using too much hard drive space
    # on saved models (in the MODEL_DIR), try making this value larger.
    VALIDATION_STEPS = 5
    
    # Matterport originally used resnet101, but I downsized to fit it on my graphics card
    #resnetの階層は50層、101層
    BACKBONE = 'resnet101'

    # To be honest, I haven't taken the time to figure out what these do
    RPN_ANCHOR_SCALES = (8, 16, 32, 64, 128)
    TRAIN_ROIS_PER_IMAGE = 32
    MAX_GT_INSTANCES = 50 
    POST_NMS_ROIS_INFERENCE = 500 
    POST_NMS_ROIS_TRAINING = 1000 
    DETECTION_MIN_CONFIDENCE = 0.9
    
config = GomiConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  512
# IMAGE_META_SIZE                20
# IMAGE_MIN_DIM                  512
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [512 512   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               50
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           gomi
# NUM_CLASSES                    8
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        500
# POST_NMS_ROIS_TRAINING         1000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                50
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               5
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# # Define the dataset
# I've attempted to make this generic to any COCO-like dataset. That means if you have another dataset defined in the COCO format, it should work.

# %% [markdown]
# import skimage.io
# class GomiDataset(utils.Dataset):
#     """ Generates a COCO-like dataset, i.e. an image dataset annotated in the style of the COCO dataset.
#         See http://cocodataset.org/#home for more information.
#     """
#     def load_data(self, annotation_json, images_dir):
#         """ Load the coco-like dataset from json
#         Args:
#             annotation_json: The path to the coco annotations json file
#             images_dir: The directory holding the images referred to by the json file
#         """
#         # Load json from file
#         with open(annotation_json) as f:
#             anno_json = json.load(f)
#
#         # Add the class names using the base method from utils.Dataset
#         source_name = "gomi"
#
#         category_list=["PETbottles","Cans","Papers","Plastic","Cardboards","Plastic Bag","Bottles"]
#         for i,category in enumerate(category_list):
#             self.add_class(source_name, i+1, category)
#
#         annotations = list(anno_json.values())  # don't need the dict keys
#         annotations = [a for a in annotations if a['regions']]
#         dataset_dir="../../garbage/train"
#         # Add images
#         count=0
#         for a in annotations:
#             # print(a)
#             # Get the x, y coordinaets of points of the polygons that make up
#             # the outline of each object instance. There are stores in the
#             # shape_attributes (see json format above)
#             polygons = [r['shape_attributes'] for r in a['regions']]
#             objects = [list(s['region_attributes']['Type'])[0] for s in a['regions']]
#
#             name_dict = {"PET bottles":1,"Cans":2,"Papers":3,"Plastic":4,"Cardboards":5,"Plastic Bag":6,"Bottles":7}
#             # key = tuple(name_dict)
#             num_ids = [name_dict[a] for a in objects]
#
#             # num_ids = [int(n['Event']) for n in objects]
#             # load_mask() needs the image size to convert polygons to masks.
#             # Unfortunately, VIA doesn't include it in JSON, so we must read
#             # the image. This is only managable since the dataset is tiny.
#             print("numids",num_ids)
#
#             image_path = os.path.abspath(os.path.join(images_dir, a['filename']))
#             image_id=int(pathlib.Path(image_path).stem[-4:]) #image_id
#             image = skimage.io.imread(image_path)
#
#             image_height, image_width = image.shape[:2]
#
#             for i in range(len(num_ids)):
#               annotation=polygons[i]
#               #segmentation=[[] for _ in range(len(num_ids))]
#               segmentation=[[]]
#               bbox_x=min(annotation['all_points_x'])
#               bbox_y=min(annotation['all_points_y'])
#               bbox_width=max(annotation['all_points_x']) - bbox_x
#               bbox_height=max(annotation['all_points_y']) - bbox_y
#               bbox=[bbox_x,bbox_y,bbox_width,bbox_height]
#               category_id=num_ids[i]
#               for j in range(len(annotation['all_points_x'])):
#                   segmentation[0].append(annotation['all_points_x'][j])
#                   segmentation[0].append(annotation['all_points_y'][j])
#
#                   image_annotations=[{'area': 1510.5,
#                                       'bbox': bbox,
#                                       'category_id': category_id,
#                                       'id': count,
#                                       'image_id': image_id,
#                                       'iscrowd': 0,
#                                       'segmentation': segmentation}]
#                   count+=1
#             self.add_image(
#                 source=source_name,
#                 image_id=image_id,
#                 path=image_path,
#                 width=image_width,
#                 height=image_height,
#                 annotations=image_annotations
#             )
#
#
#     def load_mask(self, image_id):
#         """ Load instance masks for the given image.
#         MaskRCNN expects masks in the form of a bitmap [height, width, instances].
#         Args:
#             image_id: The id of the image to load masks for
#         Returns:
#             masks: A bool array of shape [height, width, instance count] with
#                 one mask per instance.
#             class_ids: a 1D array of class IDs of the instance masks.
#         """
#         image_info = self.image_info[image_id]
#         annotations = image_info['annotations']
#         instance_masks = []
#         class_ids = []
#
#         for annotation in annotations:
#             class_id = annotation['category_id']
#             mask = Image.new('1', (image_info['width'], image_info['height']))
#             mask_draw = ImageDraw.ImageDraw(mask, '1')
#             for segmentation in annotation['segmentation']:
#                 mask_draw.polygon(segmentation, fill=1)
#                 bool_array = np.array(mask) > 0
#                 instance_masks.append(bool_array)
#                 class_ids.append(class_id)
#
#         mask = np.dstack(instance_masks)
#         class_ids = np.array(class_ids, dtype=np.int32)
#
#         return mask, class_ids

# %%
class GomiDataset(utils.Dataset):
    def load_data(self, dataset_dir, images_dir):
        """Load a subset of the bottle dataset.
        dataset_dir: Root directory of the dataset.
        subset: Subset to load: train or val
        """
        # Add classes. We have only one class to add.
        gomilist=["PETbottles","Cans","Papers","Plastic","Cardboards","Plastic Bag","Bottles"]
        for i in range(7):
            self.add_class("gomi", i+1, gomilist[i])

        # Train or validation dataset?
        # Load json from file
        # dataset_dir is json file
        with open(dataset_dir) as f:
            anno_json = json.load(f)

        # Load annotations
        # VGG Image Annotator saves each image in the form:
        # { 'filename': '28503151_5b5b7ec140_b.jpg',
        #   'regions': {
        #       '0': {
        #           'region_attributes': {},
        #           'shape_attributes': {
        #               'all_points_x': [...],
        #               'all_points_y': [...],
        #               'name': 'polygon'}},
        #       ... more regions ...
        #   },
        #   'size': 100202
        # }
        # We mostly care about the x and y coordinates of each region
        annotations = list(anno_json.values())  # don't need the dict keys
        annotations = [a for a in annotations if a['regions']]
        # The VIA tool saves images in the JSON even if they don't have any
        # annotations. Skip unannotated images.
        annotations = [a for a in annotations if a['regions']]
        # Add images
        for a in annotations:
            # print(a)
            # Get the x, y coordinaets of points of the polygons that make up
            # the outline of each object instance. There are stores in the
            # shape_attributes (see json format above)
            polygons = [r['shape_attributes'] for r in a['regions']]
            objects = [list(s['region_attributes']['Type'])[0] for s in a['regions']]

            name_dict = {"PET bottles":1,"Cans":2,"Papers":3,"Plastic":4,"Cardboards":5,"Plastic Bag":6,"Bottles":7}
            # key = tuple(name_dict)
            num_ids = [name_dict[a] for a in objects]

            # num_ids = [int(n['Event']) for n in objects]
            # load_mask() needs the image size to convert polygons to masks.
            # Unfortunately, VIA doesn't include it in JSON, so we must read
            # the image. This is only managable since the dataset is tiny.
            print("numids",num_ids)
            image_path = os.path.join(images_dir, a['filename'])
            image = skimage.io.imread(image_path)
            height, width = image.shape[:2]

            self.add_image(
                "gomi",  ## for a single class just add the name here
                image_id=a['filename'],  # use file name as a unique image id
                path=image_path,
                width=width, height=height,
                polygons=polygons,
                num_ids=num_ids)

    def load_mask(self, image_id):
        """Generate instance masks for an image.
       Returns:
        masks: A bool array of shape [height, width, instance count] with
            one mask per instance.
        class_ids: a 1D array of class IDs of the instance masks.
        """
        # If not a bottle dataset image, delegate to parent class.
        image_info = self.image_info[image_id]
        if image_info["source"] != "gomi":
            return super(self.__class__, self).load_mask(image_id)

        # Convert polygons to a bitmap mask of shape
        # [height, width, instance_count]
        info = self.image_info[image_id]
        if info["source"] != "gomi":
            return super(self.__class__, self).load_mask(image_id)
        num_ids = info['num_ids']
        mask = np.zeros([info["height"], info["width"], len(info["polygons"])],
                        dtype=np.uint8)
        for i, p in enumerate(info["polygons"]):
            # Get indexes of pixels inside the polygon and set them to 1
        	rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])

        	mask[rr, cc, i] = 1

        # Return mask, and array of class IDs of each instance. Since we have
        # one class ID only, we return an array of 1s
        # Map class names to class IDs.
        num_ids = np.array(num_ids, dtype=np.int32)
        return mask, num_ids

# %%
def train_test_split(dataset_dir,images_dir,train_size=0.68,val_size=0.3):
    with open(dataset_dir) as f:
        anno_json = json.load(f)
    anno = list(anno_json.keys())
    random.shuffle(anno)
    #annotationの分割
    train_dataset = anno[:int(train_size*len(anno))]
    val_dataset = anno[int(train_size*len(anno)):int(val_size*len(anno))+int(train_size*len(anno))]
    test_dataset = anno[int(val_size*len(anno))+int(train_size*len(anno)):]
    split_annotations_and_images(anno_json,images_dir,train_dataset,'../datasets/garbage/train/gomi.json','../datasets/garbage/train/images')
    print('train created')
    split_annotations_and_images(anno_json,images_dir,val_dataset,'../datasets/garbage/val/gomi.json','../datasets/garbage/val/images')
    print('val created')
    split_annotations_and_images(anno_json,images_dir,test_dataset,'../datasets/garbage/real_test/gomi.json','../datasets/garbage/real_test/images')
    print('test created')
    
def split_annotations_and_images(json_dataset, images_dir, anno_list, out_anno_dir, out_images_dir):    
    s='{'
    for i in anno_list:
        s += '\"' + i + '\":'+ str(json_dataset[i]) + ','
        shutil.copyfile(images_dir +'/'+ i[:-6], out_images_dir +'/'+ i[:-6])

    s = s[:-1] + '}'
    s = s.replace('\'','\"').replace('True','true')
    with open(out_anno_dir,'w') as f:
        f.write(s)

# %% [markdown]
# # Create the Training and Validation Datasets
# Make sure you download the training dataset linked at the top of this notebook. If you put the dataset somewhere else, update the paths below.

# %%
#train_test_split('../datasets/garbage/small_aug_gomi.json','../datasets/garbage/augmentated_images')

# %%
dataset_train = GomiDataset()
dataset_train.load_data('../datasets/garbage/train/gomi.json', '../datasets/garbage/train/images')
dataset_train.prepare()

dataset_val = GomiDataset()
dataset_val.load_data('../datasets/garbage/val/gomi.json', '../datasets/garbage/val/images')
dataset_val.prepare()
# Out:
# numids [3, 3, 3, 3, 3]
# numids [2, 3]
# numids [2]
# numids [2]
# numids [2, 2, 2, 2]
# numids [7]
# numids [2, 2]
# numids [6, 1]
# numids [4, 4, 4, 6, 3]
# numids [3]
# numids [4]
# numids [4, 2]
# numids [3, 3]
# numids [1, 2]
# numids [1, 2]
# numids [2]
# numids [6, 3]
# numids [2]
# numids [2, 1, 1]
# numids [2, 4, 4, 4]
# numids [3]
# numids [2]
# numids [4, 1]
# numids [1, 1, 4, 4]
# numids [3, 1, 1, 2, 2, 3]
# numids [7]
# numids [2]
# numids [5, 3, 4]
# numids [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 6, 6]
# numids [6]
# numids [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 6, 6]
# numids [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 6, 6]
# numids [1, 1, 1, 1, 1, 1, 1]
# numids [1, 2]
# numids [6]
# numids [3, 1, 4]
# numids [1, 1, 3, 4]
# numids [1, 1, 1, 1, 1, 1, 1]
# numids [7]
# numids [3, 3, 1]
# numids [6, 1]
# numids [3, 3]
# numids [4, 3]
# numids [4, 3, 3, 4, 4, 7]
# numids [1, 1, 2, 1]
# numids [6, 1]
# numids [1, 1, 2, 2]
# numids [2, 4, 4, 4]
# numids [4, 3]
# numids [3, 3, 3, 3]
# numids [1, 1, 1, 1, 1, 1, 1]
# numids [3, 3, 3]
# numids [3, 3]
# numids [3, 3, 3, 3]
# numids [4, 4, 6, 4, 3, 4, 3, 3]
# numids [6]
# numids [2, 6]
# numids [1, 1, 2, 1]
# numids [2]
# numids [1, 2]
# numids [3]
# numids [2, 3]
# numids [1, 1, 1, 1, 1, 1, 1]
# numids [1, 1, 2, 1]
# numids [2, 3]
# numids [3, 3, 3]
# numids [6, 1]
# numids [3, 1, 3]
# numids [3, 3, 3, 6]
# numids [7]
# numids [4]
# numids [1, 1, 4, 4]
# numids [3, 3, 3, 6]
# numids [3, 3, 3, 6]
# numids [7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7]
# numids [2, 3]
# numids [3, 4]
# numids [3, 2, 2, 2, 3, 4, 6]
# numids [2, 4]
# numids [1, 1, 2, 2]
# numids [2, 4]
# numids [3, 3, 3]
# numids [3, 3, 3]
# numids [4, 3]
# numids [4, 4, 6, 4, 3, 4, 3, 3]
# numids [1, 2]
# numids [1, 4, 4]
# numids [3, 4]
# numids [2, 3, 1, 2, 1]
# numids [3, 6]
# numids [2, 1]
# numids [2, 2]
# numids [3, 1]
# numids [4, 3, 3, 4, 4, 7]
# numids [2, 3]
# numids [3]
# numids [3, 3, 3]
# numids [3, 1, 1, 2, 2, 3]
# numids [1]
# numids [3, 7, 2, 7, 2, 2]
# numids [6]
# numids [3, 3, 3, 2]
# numids [2, 6]
# numids [3, 3, 3, 3]
# numids [5, 3]
# numids [4, 2]
# numids [1, 1, 1, 1, 1, 1, 1]
# numids [3, 1]
# numids [2, 3, 4, 3, 4, 4, 1, 2, 4]
# numids [2, 6]
# numids [4, 4, 5, 4]
# numids [2]
# numids [2, 1, 1]
# numids [3, 1, 3]
# numids [3, 1, 4]
# numids [4, 3, 3, 3, 1, 1]
# numids [2, 1, 1]
# numids [3, 1, 3]
# numids [3, 3, 3]
# numids [2, 2]
# numids [1, 1, 3, 4]
# numids [2, 3, 4, 3, 4, 4, 1, 2, 4]
# numids [4]
# numids [4, 3]
# numids [2, 3]
# numids [3, 4]
# numids [3, 3, 1]
# numids [2, 3]
# numids [2]
# numids [3, 3, 3, 6]
# numids [1, 1]
# numids [2, 3]
# numids [3, 3, 3, 2]
# numids [4, 2]
# numids [3, 1, 1, 4]
# numids [3, 3, 3, 3, 3]
# numids [4, 3, 4, 4, 4, 4, 4]
# numids [4, 4, 4, 6, 3]
# numids [2]
# numids [7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7]
# numids [2, 1, 1, 3]
# numids [2, 2, 2, 2]
# numids [6, 3]
# numids [3, 3, 3, 3]
# numids [4, 3, 3, 3, 1, 1]
# numids [3, 4]
# numids [2, 6]
# numids [3]
# numids [4, 1, 3, 5]
# numids [1, 1, 4, 4]
# numids [2]
# numids [3, 3, 3, 1]
# numids [4, 4, 4, 6, 3]
# numids [3, 6]
# numids [1]
# numids [1, 4, 4]
# numids [3, 1, 1, 2, 2, 3]
# numids [1, 1, 3, 4]
# numids [4]
# numids [1, 1, 1, 1, 1, 1, 1]
# numids [2, 3]
# numids [4, 3, 4, 4, 4, 4, 4]
# numids [3, 1, 4]
# numids [7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7]
# numids [4, 3, 3, 4, 4, 7]
# numids [3, 4]
# numids [1, 1, 2, 1]
# numids [1, 1, 1, 1, 1, 1, 1]
# numids [3, 3, 3]
# numids [1, 1]
# numids [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 6, 6]
# numids [6]
# numids [2, 4]
# numids [2, 3, 4, 3, 4, 4, 1, 2, 4]
# numids [2]
# numids [6, 3]
# numids [3, 3, 3, 3]
# numids [7]
# numids [4, 2]
# numids [4, 1]
# numids [7]
# numids [4, 3, 4, 4, 4, 4, 4]
# numids [6]
# numids [2]
# numids [4, 3]
# numids [6]
# numids [2, 2]
# numids [1, 2]
# numids [2, 1]
# numids [3, 3, 3, 3]
# numids [4]
# numids [5, 3]
# numids [3, 3, 3]
# numids [2, 1, 1, 3]
# numids [7]
# numids [2, 3, 1, 2, 1]
# numids [4, 3, 3, 3, 1, 1]
# numids [4, 4, 5, 4]
# numids [3, 1, 4]
# numids [2]
# numids [2]
# numids [4]
# numids [2]
# numids [2]
# numids [4, 3]
# numids [1]
# numids [1, 1, 2, 2]
# numids [3, 1, 1, 4]
# numids [4, 3, 3, 3, 1, 1]
# numids [4, 4, 6, 4, 3, 4, 3, 3]
# numids [2, 4, 4, 4]
# numids [3, 1, 1, 4]
# numids [3, 1]
# numids [2, 2]
# numids [3, 6]
# numids [3, 4]
# numids [7]
# numids [3, 4]
# numids [2, 3]
# numids [4]
# numids [1, 4, 4]
# numids [3, 6]
# numids [3, 3, 1]
# numids [2, 3]
# numids [2, 1, 1, 3]
# numids [3, 4]
# numids [3, 3, 1]
# numids [3, 7, 2, 7, 2, 2]
# numids [3, 3, 3, 3, 3]
# numids [3, 2, 2, 2, 3, 4, 6]
# numids [2, 3]
# numids [4, 3]
# numids [4, 1]
# numids [1, 2]
# numids [2, 2, 2, 2]
# numids [4]
# numids [5, 3, 4]
# numids [5, 3, 4]
# numids [2]
# numids [3, 3, 3]
# numids [3]
# numids [3, 1, 3]
# numids [1, 1]
# numids [3, 3, 3, 1]
# numids [4, 3]
# numids [1, 1]
# numids [4]
# numids [3, 3, 3]
# numids [3, 3]
# numids [2, 3, 1, 2, 1]
# numids [2, 4]
# numids [4, 4, 5, 4]
# numids [7]
# numids [1, 2]
# numids [6]
# numids [4, 4, 6, 4, 3, 4, 3, 3]
# numids [3, 3, 3]
# numids [3]
# numids [3, 4]
# numids [3]
# numids [3, 3, 3, 1]
# numids [2]
# numids [3, 4]
# numids [1]
# numids [4, 1]
# numids [1, 2]
# numids [1]
# numids [1]
# numids [1, 1, 4, 4]
# numids [7]
# numids [2, 2]
# numids [1, 1, 2, 2]
# numids [4, 3]
# numids [3, 3, 3]
# numids [1, 2]
# numids [2]
# numids [4, 3]
# numids [3, 4]
# numids [4, 1, 3, 5]
# numids [7]
# numids [2, 3]
# numids [2, 6]
# numids [2, 3, 4, 3, 4, 4, 1, 2, 4]
# numids [5, 3]
# numids [3, 2, 2, 2, 3, 4, 6]
# numids [3, 3, 3, 3]
# numids [4]
# numids [1, 4, 4]
# numids [4, 1, 3, 5]
# numids [4, 3]
# numids [3]
# numids [3]
# numids [3, 7, 2, 7, 2, 2]
# numids [3, 3, 3, 3]
# numids [2, 4, 4, 4]
# numids [4, 3]
# numids [5, 3]
# numids [2, 1]
# numids [2, 6]
# numids [1, 1, 3, 4]
# numids [3, 3, 3, 3, 3]
# numids [2]
# numids [2, 1]
# numids [4, 3, 4, 4, 4, 4, 4]
# numids [3, 3, 3]
# numids [3, 1, 1, 2, 2, 3]
# numids [1, 1, 1, 1, 1, 1, 1]
# numids [2, 1, 1]
# numids [3]
# numids [3, 3, 3, 1]
# numids [2, 6]
# numids [2, 2]
# numids [2, 6]
# numids [3, 3, 3]
# numids [3, 3, 3]
# numids [1, 2]
# numids [3, 3, 3]
# numids [4, 3, 3, 4, 4, 7]
# numids [3, 3, 3]
# numids [2]
# numids [2, 3]
# numids [3, 4]
# numids [5, 3, 4]
# numids [1]
# numids [4, 4, 5, 4]
# numids [4]
# numids [3, 3]
# numids [3, 3]
# numids [3, 3, 3]
# numids [3, 7, 2, 7, 2, 2]
# numids [2, 3]
# numids [2, 2]
# numids [7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7]
# numids [2, 2, 2, 2]
# numids [1, 2]
# numids [3, 2, 2, 2, 3, 4, 6]
# numids [4, 1, 3, 5]
# numids [4]
# numids [2]
# numids [3, 3, 3, 2]
# numids [3, 3]
# numids [2, 3, 1, 2, 1]
# numids [1]
# numids [3, 3, 3, 2]
# numids [2, 1, 1, 3]
# numids [3, 3, 3]
# numids [3, 3, 3]
# numids [7]

# %% [markdown]
# ## Display a few images from the training dataset

# %%
dataset = dataset_train
image_ids = np.random.choice(dataset.image_ids, 4)
for image_id in image_ids:
    image = dataset.load_image(image_id)
    mask, class_ids = dataset.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset.class_names,4)

# %% [markdown]
# # Create the Training Model and Train
# This code is largely borrowed from the train_shapes.ipynb notebook.

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)
# Out:
# WARNING:tensorflow:From /home/gonken-rtx-11/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
# Which weights to start with?
init_with = "coco"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last(), by_name=True)

# %% [markdown]
# ## Training
#
# Train in two stages:
#
# 1. Only the heads. Here we're freezing all the backbone layers and training only the randomly initialized layers (i.e. the ones that we didn't use pre-trained weights from MS COCO). To train only the head layers, pass layers='heads' to the train() function.
#
# 2. Fine-tune all layers. For this simple example it's not necessary, but we're including it to show the process. Simply pass layers="all to train all layers.

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.
start_train = time.time()
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=100, 
            layers='heads')
end_train = time.time()
minutes = round((end_train - start_train) / 60, 2)
print(f'Training took {minutes} minutes')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: ../../aktwelve_mask_rcnn/g_logs/gomi20210415T1644/mask_rcnn_gomi_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layers with arguments in `__init__` must override `get_config`.
# Epoch 1/100
# /home/gonken-rtx-11/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /home/gonken-rtx-11/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /home/gonken-rtx-11/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 50/50 [==============================] - 185s 4s/step - loss: 0.6996 - rpn_class_loss: 0.0033 - rpn_bbox_loss: 0.1015 - mrcnn_class_loss: 0.1802 - mrcnn_bbox_loss: 0.1429 - mrcnn_mask_loss: 0.2716 - val_loss: 3.5828 - val_rpn_class_loss: 0.0151 - val_rpn_bbox_loss: 3.5677 - val_mrcnn_class_loss: 3.5763e-07 - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 2/100
# 50/50 [==============================] - 137s 3s/step - loss: 0.7818 - rpn_class_loss: 0.0080 - rpn_bbox_loss: 0.1748 - mrcnn_class_loss: 0.1286 - mrcnn_bbox_loss: 0.1964 - mrcnn_mask_loss: 0.2739 - val_loss: 5.4084 - val_rpn_class_loss: 0.0381 - val_rpn_bbox_loss: 3.2831 - val_mrcnn_class_loss: 0.7750 - val_mrcnn_bbox_loss: 1.0980 - val_mrcnn_mask_loss: 0.2141
# Epoch 3/100
# 50/50 [==============================] - 136s 3s/step - loss: 0.9965 - rpn_class_loss: 0.0197 - rpn_bbox_loss: 0.5221 - mrcnn_class_loss: 0.1117 - mrcnn_bbox_loss: 0.2594 - mrcnn_mask_loss: 0.0835 - val_loss: 2.9869 - val_rpn_class_loss: 0.0070 - val_rpn_bbox_loss: 1.2168 - val_mrcnn_class_loss: 0.6732 - val_mrcnn_bbox_loss: 0.7263 - val_mrcnn_mask_loss: 0.3636
# Epoch 4/100
# 50/50 [==============================] - 137s 3s/step - loss: 0.7231 - rpn_class_loss: 0.0094 - rpn_bbox_loss: 0.3841 - mrcnn_class_loss: 0.1288 - mrcnn_bbox_loss: 0.1195 - mrcnn_mask_loss: 0.0812 - val_loss: 2.5841 - val_rpn_class_loss: 0.0165 - val_rpn_bbox_loss: 1.2709 - val_mrcnn_class_loss: 0.4611 - val_mrcnn_bbox_loss: 0.5494 - val_mrcnn_mask_loss: 0.2863
# Epoch 5/100
# 50/50 [==============================] - 142s 3s/step - loss: 0.6201 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.2327 - mrcnn_class_loss: 0.1471 - mrcnn_bbox_loss: 0.1192 - mrcnn_mask_loss: 0.1179 - val_loss: 2.7432 - val_rpn_class_loss: 0.0194 - val_rpn_bbox_loss: 1.9889 - val_mrcnn_class_loss: 0.0211 - val_mrcnn_bbox_loss: 0.6101 - val_mrcnn_mask_loss: 0.1037
# Epoch 6/100
# 50/50 [==============================] - 136s 3s/step - loss: 0.2371 - rpn_class_loss: 9.9334e-04 - rpn_bbox_loss: 0.0159 - mrcnn_class_loss: 0.0665 - mrcnn_bbox_loss: 0.0739 - mrcnn_mask_loss: 0.0797 - val_loss: 3.0044 - val_rpn_class_loss: 0.0144 - val_rpn_bbox_loss: 1.8040 - val_mrcnn_class_loss: 0.5363 - val_mrcnn_bbox_loss: 0.4471 - val_mrcnn_mask_loss: 0.2026
# Epoch 7/100
# 50/50 [==============================] - 136s 3s/step - loss: 0.3239 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.0600 - mrcnn_class_loss: 0.0633 - mrcnn_bbox_loss: 0.0933 - mrcnn_mask_loss: 0.1029 - val_loss: 1.9775 - val_rpn_class_loss: 0.0116 - val_rpn_bbox_loss: 1.2131 - val_mrcnn_class_loss: 0.3404 - val_mrcnn_bbox_loss: 0.2304 - val_mrcnn_mask_loss: 0.1820
# Epoch 8/100
# 50/50 [==============================] - 138s 3s/step - loss: 0.1889 - rpn_class_loss: 0.0023 - rpn_bbox_loss: 0.0327 - mrcnn_class_loss: 0.0470 - mrcnn_bbox_loss: 0.0535 - mrcnn_mask_loss: 0.0535 - val_loss: 2.2847 - val_rpn_class_loss: 0.0092 - val_rpn_bbox_loss: 1.2745 - val_mrcnn_class_loss: 0.6311 - val_mrcnn_bbox_loss: 0.1882 - val_mrcnn_mask_loss: 0.1817
# Epoch 9/100
# 50/50 [==============================] - 138s 3s/step - loss: 0.2008 - rpn_class_loss: 0.0022 - rpn_bbox_loss: 0.0513 - mrcnn_class_loss: 0.0474 - mrcnn_bbox_loss: 0.0512 - mrcnn_mask_loss: 0.0488 - val_loss: 2.0382 - val_rpn_class_loss: 0.0101 - val_rpn_bbox_loss: 1.2540 - val_mrcnn_class_loss: 0.4751 - val_mrcnn_bbox_loss: 0.2093 - val_mrcnn_mask_loss: 0.0897
# Epoch 10/100
# 50/50 [==============================] - 148s 3s/step - loss: 0.2744 - rpn_class_loss: 0.0019 - rpn_bbox_loss: 0.0654 - mrcnn_class_loss: 0.0668 - mrcnn_bbox_loss: 0.0607 - mrcnn_mask_loss: 0.0796 - val_loss: 2.0583 - val_rpn_class_loss: 0.0129 - val_rpn_bbox_loss: 1.5896 - val_mrcnn_class_loss: 0.0377 - val_mrcnn_bbox_loss: 0.3151 - val_mrcnn_mask_loss: 0.1030
# Epoch 11/100
# 50/50 [==============================] - 139s 3s/step - loss: 0.1360 - rpn_class_loss: 7.9090e-04 - rpn_bbox_loss: 0.0097 - mrcnn_class_loss: 0.0301 - mrcnn_bbox_loss: 0.0387 - mrcnn_mask_loss: 0.0568 - val_loss: 2.3397 - val_rpn_class_loss: 0.0118 - val_rpn_bbox_loss: 1.7742 - val_mrcnn_class_loss: 0.0913 - val_mrcnn_bbox_loss: 0.3604 - val_mrcnn_mask_loss: 0.1020
# Epoch 12/100
# 50/50 [==============================] - 148s 3s/step - loss: 0.2494 - rpn_class_loss: 0.0019 - rpn_bbox_loss: 0.0454 - mrcnn_class_loss: 0.0580 - mrcnn_bbox_loss: 0.0782 - mrcnn_mask_loss: 0.0660 - val_loss: 2.1673 - val_rpn_class_loss: 0.0108 - val_rpn_bbox_loss: 1.4609 - val_mrcnn_class_loss: 0.2549 - val_mrcnn_bbox_loss: 0.3082 - val_mrcnn_mask_loss: 0.1325
# Epoch 13/100
# 50/50 [==============================] - 148s 3s/step - loss: 0.1649 - rpn_class_loss: 0.0013 - rpn_bbox_loss: 0.0324 - mrcnn_class_loss: 0.0371 - mrcnn_bbox_loss: 0.0511 - mrcnn_mask_loss: 0.0431 - val_loss: 2.2671 - val_rpn_class_loss: 0.0105 - val_rpn_bbox_loss: 1.3438 - val_mrcnn_class_loss: 0.3970 - val_mrcnn_bbox_loss: 0.3963 - val_mrcnn_mask_loss: 0.1194
# Epoch 14/100
# 50/50 [==============================] - 146s 3s/step - loss: 0.2539 - rpn_class_loss: 0.0013 - rpn_bbox_loss: 0.0507 - mrcnn_class_loss: 0.0964 - mrcnn_bbox_loss: 0.0512 - mrcnn_mask_loss: 0.0542 - val_loss: 2.3477 - val_rpn_class_loss: 0.0125 - val_rpn_bbox_loss: 1.5953 - val_mrcnn_class_loss: 0.3336 - val_mrcnn_bbox_loss: 0.2213 - val_mrcnn_mask_loss: 0.1850
# Epoch 15/100
# 50/50 [==============================] - 151s 3s/step - loss: 0.1733 - rpn_class_loss: 9.2059e-04 - rpn_bbox_loss: 0.0326 - mrcnn_class_loss: 0.0379 - mrcnn_bbox_loss: 0.0478 - mrcnn_mask_loss: 0.0540 - val_loss: 2.7456 - val_rpn_class_loss: 0.0096 - val_rpn_bbox_loss: 1.7723 - val_mrcnn_class_loss: 0.5204 - val_mrcnn_bbox_loss: 0.2967 - val_mrcnn_mask_loss: 0.1466
# Epoch 16/100
# 50/50 [==============================] - 137s 3s/step - loss: 0.1496 - rpn_class_loss: 6.5977e-04 - rpn_bbox_loss: 0.0062 - mrcnn_class_loss: 0.0566 - mrcnn_bbox_loss: 0.0337 - mrcnn_mask_loss: 0.0525 - val_loss: 2.5033 - val_rpn_class_loss: 0.0123 - val_rpn_bbox_loss: 1.9384 - val_mrcnn_class_loss: 0.1017 - val_mrcnn_bbox_loss: 0.2759 - val_mrcnn_mask_loss: 0.1750
# Epoch 17/100
# 50/50 [==============================] - 136s 3s/step - loss: 0.1570 - rpn_class_loss: 0.0010 - rpn_bbox_loss: 0.0175 - mrcnn_class_loss: 0.0492 - mrcnn_bbox_loss: 0.0386 - mrcnn_mask_loss: 0.0507 - val_loss: 2.3818 - val_rpn_class_loss: 0.0086 - val_rpn_bbox_loss: 1.5707 - val_mrcnn_class_loss: 0.4363 - val_mrcnn_bbox_loss: 0.2137 - val_mrcnn_mask_loss: 0.1524
# Epoch 18/100
# 50/50 [==============================] - 136s 3s/step - loss: 0.1420 - rpn_class_loss: 9.7630e-04 - rpn_bbox_loss: 0.0357 - mrcnn_class_loss: 0.0392 - mrcnn_bbox_loss: 0.0329 - mrcnn_mask_loss: 0.0333 - val_loss: 2.1283 - val_rpn_class_loss: 0.0106 - val_rpn_bbox_loss: 1.2442 - val_mrcnn_class_loss: 0.5439 - val_mrcnn_bbox_loss: 0.2136 - val_mrcnn_mask_loss: 0.1160
# Epoch 19/100
# 50/50 [==============================] - 137s 3s/step - loss: 0.2056 - rpn_class_loss: 0.0013 - rpn_bbox_loss: 0.0894 - mrcnn_class_loss: 0.0444 - mrcnn_bbox_loss: 0.0304 - mrcnn_mask_loss: 0.0400 - val_loss: 2.5949 - val_rpn_class_loss: 0.0284 - val_rpn_bbox_loss: 1.6329 - val_mrcnn_class_loss: 0.4850 - val_mrcnn_bbox_loss: 0.3399 - val_mrcnn_mask_loss: 0.1087
# Epoch 20/100
# 50/50 [==============================] - 145s 3s/step - loss: 0.2072 - rpn_class_loss: 0.0015 - rpn_bbox_loss: 0.0258 - mrcnn_class_loss: 0.0767 - mrcnn_bbox_loss: 0.0430 - mrcnn_mask_loss: 0.0602 - val_loss: 2.3500 - val_rpn_class_loss: 0.0274 - val_rpn_bbox_loss: 1.6302 - val_mrcnn_class_loss: 0.2827 - val_mrcnn_bbox_loss: 0.3078 - val_mrcnn_mask_loss: 0.1020
# Epoch 21/100
# 50/50 [==============================] - 143s 3s/step - loss: 0.1552 - rpn_class_loss: 6.2226e-04 - rpn_bbox_loss: 0.0112 - mrcnn_class_loss: 0.0503 - mrcnn_bbox_loss: 0.0438 - mrcnn_mask_loss: 0.0494 - val_loss: 2.3838 - val_rpn_class_loss: 0.0269 - val_rpn_bbox_loss: 1.5702 - val_mrcnn_class_loss: 0.3348 - val_mrcnn_bbox_loss: 0.2961 - val_mrcnn_mask_loss: 0.1558
# Epoch 22/100
# 50/50 [==============================] - 148s 3s/step - loss: 0.1072 - rpn_class_loss: 8.5471e-04 - rpn_bbox_loss: 0.0081 - mrcnn_class_loss: 0.0315 - mrcnn_bbox_loss: 0.0228 - mrcnn_mask_loss: 0.0438 - val_loss: 2.8492 - val_rpn_class_loss: 0.0260 - val_rpn_bbox_loss: 1.8488 - val_mrcnn_class_loss: 0.5422 - val_mrcnn_bbox_loss: 0.3251 - val_mrcnn_mask_loss: 0.1070
# Epoch 23/100
# 50/50 [==============================] - 143s 3s/step - loss: 0.0746 - rpn_class_loss: 8.6615e-04 - rpn_bbox_loss: 0.0105 - mrcnn_class_loss: 0.0173 - mrcnn_bbox_loss: 0.0172 - mrcnn_mask_loss: 0.0287 - val_loss: 3.9412 - val_rpn_class_loss: 0.0257 - val_rpn_bbox_loss: 1.7575 - val_mrcnn_class_loss: 1.7544 - val_mrcnn_bbox_loss: 0.3281 - val_mrcnn_mask_loss: 0.0754
# Epoch 24/100
# 50/50 [==============================] - 151s 3s/step - loss: 0.1817 - rpn_class_loss: 8.6881e-04 - rpn_bbox_loss: 0.0359 - mrcnn_class_loss: 0.0565 - mrcnn_bbox_loss: 0.0253 - mrcnn_mask_loss: 0.0632 - val_loss: 3.0377 - val_rpn_class_loss: 0.0223 - val_rpn_bbox_loss: 2.1690 - val_mrcnn_class_loss: 0.5065 - val_mrcnn_bbox_loss: 0.2127 - val_mrcnn_mask_loss: 0.1271
# Epoch 25/100
# 50/50 [==============================] - 148s 3s/step - loss: 0.1085 - rpn_class_loss: 2.8317e-04 - rpn_bbox_loss: 0.0067 - mrcnn_class_loss: 0.0300 - mrcnn_bbox_loss: 0.0240 - mrcnn_mask_loss: 0.0475 - val_loss: 2.6140 - val_rpn_class_loss: 0.0263 - val_rpn_bbox_loss: 1.8253 - val_mrcnn_class_loss: 0.4227 - val_mrcnn_bbox_loss: 0.2238 - val_mrcnn_mask_loss: 0.1159
# Epoch 26/100
# 50/50 [==============================] - 142s 3s/step - loss: 0.0996 - rpn_class_loss: 5.5647e-04 - rpn_bbox_loss: 0.0050 - mrcnn_class_loss: 0.0304 - mrcnn_bbox_loss: 0.0222 - mrcnn_mask_loss: 0.0416 - val_loss: 3.0824 - val_rpn_class_loss: 0.0262 - val_rpn_bbox_loss: 1.8409 - val_mrcnn_class_loss: 0.8603 - val_mrcnn_bbox_loss: 0.2329 - val_mrcnn_mask_loss: 0.1222
# Epoch 27/100
# 50/50 [==============================] - 149s 3s/step - loss: 0.0585 - rpn_class_loss: 6.3765e-04 - rpn_bbox_loss: 0.0059 - mrcnn_class_loss: 0.0080 - mrcnn_bbox_loss: 0.0117 - mrcnn_mask_loss: 0.0323 - val_loss: 3.6749 - val_rpn_class_loss: 0.0251 - val_rpn_bbox_loss: 1.8930 - val_mrcnn_class_loss: 1.3340 - val_mrcnn_bbox_loss: 0.2397 - val_mrcnn_mask_loss: 0.1830
# Epoch 28/100
# 50/50 [==============================] - 148s 3s/step - loss: 0.0611 - rpn_class_loss: 4.0880e-04 - rpn_bbox_loss: 0.0112 - mrcnn_class_loss: 0.0166 - mrcnn_bbox_loss: 0.0102 - mrcnn_mask_loss: 0.0226 - val_loss: 4.2247 - val_rpn_class_loss: 0.0265 - val_rpn_bbox_loss: 1.8471 - val_mrcnn_class_loss: 2.0135 - val_mrcnn_bbox_loss: 0.2241 - val_mrcnn_mask_loss: 0.1135
# Epoch 29/100
# 50/50 [==============================] - 152s 3s/step - loss: 0.0934 - rpn_class_loss: 7.0771e-04 - rpn_bbox_loss: 0.0108 - mrcnn_class_loss: 0.0258 - mrcnn_bbox_loss: 0.0138 - mrcnn_mask_loss: 0.0422 - val_loss: 3.8663 - val_rpn_class_loss: 0.0255 - val_rpn_bbox_loss: 1.7668 - val_mrcnn_class_loss: 1.8034 - val_mrcnn_bbox_loss: 0.1726 - val_mrcnn_mask_loss: 0.0981
# Epoch 30/100
# 50/50 [==============================] - 147s 3s/step - loss: 0.0999 - rpn_class_loss: 1.4161e-04 - rpn_bbox_loss: 0.0036 - mrcnn_class_loss: 0.0232 - mrcnn_bbox_loss: 0.0290 - mrcnn_mask_loss: 0.0439 - val_loss: 2.9662 - val_rpn_class_loss: 0.0310 - val_rpn_bbox_loss: 1.4043 - val_mrcnn_class_loss: 1.2211 - val_mrcnn_bbox_loss: 0.2025 - val_mrcnn_mask_loss: 0.1072
# Epoch 31/100
# 50/50 [==============================] - 147s 3s/step - loss: 0.0861 - rpn_class_loss: 5.8773e-04 - rpn_bbox_loss: 0.0024 - mrcnn_class_loss: 0.0270 - mrcnn_bbox_loss: 0.0145 - mrcnn_mask_loss: 0.0416 - val_loss: 2.9471 - val_rpn_class_loss: 0.0298 - val_rpn_bbox_loss: 1.4246 - val_mrcnn_class_loss: 1.1379 - val_mrcnn_bbox_loss: 0.2398 - val_mrcnn_mask_loss: 0.1151
# Epoch 32/100
# 50/50 [==============================] - 151s 3s/step - loss: 0.0811 - rpn_class_loss: 6.0875e-04 - rpn_bbox_loss: 0.0233 - mrcnn_class_loss: 0.0168 - mrcnn_bbox_loss: 0.0092 - mrcnn_mask_loss: 0.0312 - val_loss: 3.1389 - val_rpn_class_loss: 0.0253 - val_rpn_bbox_loss: 1.5161 - val_mrcnn_class_loss: 1.1993 - val_mrcnn_bbox_loss: 0.2354 - val_mrcnn_mask_loss: 0.1628
# Epoch 33/100
# 50/50 [==============================] - 146s 3s/step - loss: 0.0811 - rpn_class_loss: 4.9585e-04 - rpn_bbox_loss: 0.0112 - mrcnn_class_loss: 0.0360 - mrcnn_bbox_loss: 0.0086 - mrcnn_mask_loss: 0.0248 - val_loss: 2.6383 - val_rpn_class_loss: 0.0265 - val_rpn_bbox_loss: 1.5736 - val_mrcnn_class_loss: 0.6276 - val_mrcnn_bbox_loss: 0.2799 - val_mrcnn_mask_loss: 0.1307
# Epoch 34/100
# 50/50 [==============================] - 150s 3s/step - loss: 0.0920 - rpn_class_loss: 4.5595e-04 - rpn_bbox_loss: 0.0045 - mrcnn_class_loss: 0.0384 - mrcnn_bbox_loss: 0.0105 - mrcnn_mask_loss: 0.0382 - val_loss: 2.8107 - val_rpn_class_loss: 0.0291 - val_rpn_bbox_loss: 1.6361 - val_mrcnn_class_loss: 0.6609 - val_mrcnn_bbox_loss: 0.3768 - val_mrcnn_mask_loss: 0.1079
# Epoch 35/100
# 50/50 [==============================] - 144s 3s/step - loss: 0.0713 - rpn_class_loss: 9.8228e-05 - rpn_bbox_loss: 0.0010 - mrcnn_class_loss: 0.0184 - mrcnn_bbox_loss: 0.0071 - mrcnn_mask_loss: 0.0447 - val_loss: 2.5664 - val_rpn_class_loss: 0.0307 - val_rpn_bbox_loss: 1.4996 - val_mrcnn_class_loss: 0.6264 - val_mrcnn_bbox_loss: 0.2792 - val_mrcnn_mask_loss: 0.1305
# Epoch 36/100
# 50/50 [==============================] - 151s 3s/step - loss: 0.0770 - rpn_class_loss: 3.8072e-04 - rpn_bbox_loss: 0.0044 - mrcnn_class_loss: 0.0251 - mrcnn_bbox_loss: 0.0106 - mrcnn_mask_loss: 0.0365 - val_loss: 2.6246 - val_rpn_class_loss: 0.0270 - val_rpn_bbox_loss: 1.5014 - val_mrcnn_class_loss: 0.7786 - val_mrcnn_bbox_loss: 0.1842 - val_mrcnn_mask_loss: 0.1333
# Epoch 37/100
# 50/50 [==============================] - 153s 3s/step - loss: 0.0603 - rpn_class_loss: 3.8213e-04 - rpn_bbox_loss: 0.0037 - mrcnn_class_loss: 0.0227 - mrcnn_bbox_loss: 0.0074 - mrcnn_mask_loss: 0.0261 - val_loss: 2.8196 - val_rpn_class_loss: 0.0249 - val_rpn_bbox_loss: 1.4896 - val_mrcnn_class_loss: 0.9539 - val_mrcnn_bbox_loss: 0.1940 - val_mrcnn_mask_loss: 0.1573
# Epoch 38/100
# 50/50 [==============================] - 155s 3s/step - loss: 0.0822 - rpn_class_loss: 3.3490e-04 - rpn_bbox_loss: 0.0119 - mrcnn_class_loss: 0.0303 - mrcnn_bbox_loss: 0.0139 - mrcnn_mask_loss: 0.0258 - val_loss: 2.4595 - val_rpn_class_loss: 0.0262 - val_rpn_bbox_loss: 1.6103 - val_mrcnn_class_loss: 0.4558 - val_mrcnn_bbox_loss: 0.2272 - val_mrcnn_mask_loss: 0.1400
# Epoch 39/100
# 50/50 [==============================] - 152s 3s/step - loss: 0.0879 - rpn_class_loss: 3.7871e-04 - rpn_bbox_loss: 0.0097 - mrcnn_class_loss: 0.0213 - mrcnn_bbox_loss: 0.0177 - mrcnn_mask_loss: 0.0387 - val_loss: 3.2588 - val_rpn_class_loss: 0.0348 - val_rpn_bbox_loss: 1.8077 - val_mrcnn_class_loss: 1.0556 - val_mrcnn_bbox_loss: 0.2593 - val_mrcnn_mask_loss: 0.1014
# Epoch 40/100
# 50/50 [==============================] - 147s 3s/step - loss: 0.0816 - rpn_class_loss: 1.1617e-04 - rpn_bbox_loss: 6.5791e-04 - mrcnn_class_loss: 0.0375 - mrcnn_bbox_loss: 0.0079 - mrcnn_mask_loss: 0.0355 - val_loss: 3.5149 - val_rpn_class_loss: 0.0341 - val_rpn_bbox_loss: 1.7963 - val_mrcnn_class_loss: 1.3880 - val_mrcnn_bbox_loss: 0.1911 - val_mrcnn_mask_loss: 0.1053
# Epoch 41/100
# 50/50 [==============================] - 151s 3s/step - loss: 0.0745 - rpn_class_loss: 5.3992e-04 - rpn_bbox_loss: 0.0038 - mrcnn_class_loss: 0.0153 - mrcnn_bbox_loss: 0.0208 - mrcnn_mask_loss: 0.0340 - val_loss: 3.2316 - val_rpn_class_loss: 0.0330 - val_rpn_bbox_loss: 1.7764 - val_mrcnn_class_loss: 1.0326 - val_mrcnn_bbox_loss: 0.2637 - val_mrcnn_mask_loss: 0.1258
# Epoch 42/100
# 50/50 [==============================] - 151s 3s/step - loss: 0.1009 - rpn_class_loss: 4.0450e-04 - rpn_bbox_loss: 0.0132 - mrcnn_class_loss: 0.0313 - mrcnn_bbox_loss: 0.0264 - mrcnn_mask_loss: 0.0297 - val_loss: 3.3500 - val_rpn_class_loss: 0.0309 - val_rpn_bbox_loss: 1.6246 - val_mrcnn_class_loss: 1.3177 - val_mrcnn_bbox_loss: 0.2304 - val_mrcnn_mask_loss: 0.1465
# Epoch 43/100
# 50/50 [==============================] - 157s 3s/step - loss: 0.0881 - rpn_class_loss: 5.7071e-04 - rpn_bbox_loss: 0.0164 - mrcnn_class_loss: 0.0237 - mrcnn_bbox_loss: 0.0176 - mrcnn_mask_loss: 0.0299 - val_loss: 2.5244 - val_rpn_class_loss: 0.0286 - val_rpn_bbox_loss: 1.6706 - val_mrcnn_class_loss: 0.4986 - val_mrcnn_bbox_loss: 0.2289 - val_mrcnn_mask_loss: 0.0976
# Epoch 44/100
# 50/50 [==============================] - 159s 3s/step - loss: 0.0834 - rpn_class_loss: 4.1884e-04 - rpn_bbox_loss: 0.0061 - mrcnn_class_loss: 0.0205 - mrcnn_bbox_loss: 0.0150 - mrcnn_mask_loss: 0.0413 - val_loss: 3.2485 - val_rpn_class_loss: 0.0262 - val_rpn_bbox_loss: 1.9161 - val_mrcnn_class_loss: 0.9351 - val_mrcnn_bbox_loss: 0.2740 - val_mrcnn_mask_loss: 0.0971
# Epoch 45/100
# 50/50 [==============================] - 148s 3s/step - loss: 0.0554 - rpn_class_loss: 1.4681e-04 - rpn_bbox_loss: 9.5765e-04 - mrcnn_class_loss: 0.0097 - mrcnn_bbox_loss: 0.0082 - mrcnn_mask_loss: 0.0364 - val_loss: 3.0635 - val_rpn_class_loss: 0.0250 - val_rpn_bbox_loss: 1.8816 - val_mrcnn_class_loss: 0.7309 - val_mrcnn_bbox_loss: 0.2406 - val_mrcnn_mask_loss: 0.1852
# Epoch 46/100
# 50/50 [==============================] - 151s 3s/step - loss: 0.0473 - rpn_class_loss: 3.3910e-04 - rpn_bbox_loss: 0.0020 - mrcnn_class_loss: 0.0110 - mrcnn_bbox_loss: 0.0052 - mrcnn_mask_loss: 0.0288 - val_loss: 3.7133 - val_rpn_class_loss: 0.0232 - val_rpn_bbox_loss: 1.8943 - val_mrcnn_class_loss: 1.4289 - val_mrcnn_bbox_loss: 0.2148 - val_mrcnn_mask_loss: 0.1520
# Epoch 47/100
# 50/50 [==============================] - 141s 3s/step - loss: 0.0426 - rpn_class_loss: 4.1507e-04 - rpn_bbox_loss: 0.0047 - mrcnn_class_loss: 0.0110 - mrcnn_bbox_loss: 0.0048 - mrcnn_mask_loss: 0.0217 - val_loss: 3.6495 - val_rpn_class_loss: 0.0217 - val_rpn_bbox_loss: 1.7983 - val_mrcnn_class_loss: 1.3990 - val_mrcnn_bbox_loss: 0.2495 - val_mrcnn_mask_loss: 0.1810
# Epoch 48/100
# 50/50 [==============================] - 139s 3s/step - loss: 0.0705 - rpn_class_loss: 3.3389e-04 - rpn_bbox_loss: 0.0041 - mrcnn_class_loss: 0.0278 - mrcnn_bbox_loss: 0.0094 - mrcnn_mask_loss: 0.0288 - val_loss: 2.7288 - val_rpn_class_loss: 0.0288 - val_rpn_bbox_loss: 1.6871 - val_mrcnn_class_loss: 0.6972 - val_mrcnn_bbox_loss: 0.2029 - val_mrcnn_mask_loss: 0.1128
# Epoch 49/100
# 50/50 [==============================] - 152s 3s/step - loss: 0.0681 - rpn_class_loss: 1.8141e-04 - rpn_bbox_loss: 0.0028 - mrcnn_class_loss: 0.0195 - mrcnn_bbox_loss: 0.0106 - mrcnn_mask_loss: 0.0349 - val_loss: 3.7670 - val_rpn_class_loss: 0.0301 - val_rpn_bbox_loss: 1.6040 - val_mrcnn_class_loss: 1.7450 - val_mrcnn_bbox_loss: 0.2389 - val_mrcnn_mask_loss: 0.1490
# Epoch 50/100
# 50/50 [==============================] - 148s 3s/step - loss: 0.0729 - rpn_class_loss: 1.6981e-04 - rpn_bbox_loss: 0.0016 - mrcnn_class_loss: 0.0262 - mrcnn_bbox_loss: 0.0087 - mrcnn_mask_loss: 0.0362 - val_loss: 2.4367 - val_rpn_class_loss: 0.0283 - val_rpn_bbox_loss: 1.4283 - val_mrcnn_class_loss: 0.6437 - val_mrcnn_bbox_loss: 0.1824 - val_mrcnn_mask_loss: 0.1539
# Epoch 51/100
# 50/50 [==============================] - 152s 3s/step - loss: 0.0593 - rpn_class_loss: 3.0058e-04 - rpn_bbox_loss: 0.0049 - mrcnn_class_loss: 0.0143 - mrcnn_bbox_loss: 0.0101 - mrcnn_mask_loss: 0.0297 - val_loss: 2.8959 - val_rpn_class_loss: 0.0275 - val_rpn_bbox_loss: 1.5013 - val_mrcnn_class_loss: 0.8976 - val_mrcnn_bbox_loss: 0.3073 - val_mrcnn_mask_loss: 0.1622
# Epoch 52/100
# 50/50 [==============================] - 151s 3s/step - loss: 0.0498 - rpn_class_loss: 3.0672e-04 - rpn_bbox_loss: 0.0039 - mrcnn_class_loss: 0.0162 - mrcnn_bbox_loss: 0.0066 - mrcnn_mask_loss: 0.0227 - val_loss: 2.8513 - val_rpn_class_loss: 0.0278 - val_rpn_bbox_loss: 1.5965 - val_mrcnn_class_loss: 0.8614 - val_mrcnn_bbox_loss: 0.2302 - val_mrcnn_mask_loss: 0.1355
# Epoch 53/100
# 50/50 [==============================] - 149s 3s/step - loss: 0.0766 - rpn_class_loss: 5.8563e-04 - rpn_bbox_loss: 0.0059 - mrcnn_class_loss: 0.0283 - mrcnn_bbox_loss: 0.0110 - mrcnn_mask_loss: 0.0308 - val_loss: 2.7509 - val_rpn_class_loss: 0.0264 - val_rpn_bbox_loss: 1.6388 - val_mrcnn_class_loss: 0.7443 - val_mrcnn_bbox_loss: 0.2230 - val_mrcnn_mask_loss: 0.1184
# Epoch 54/100
# 50/50 [==============================] - 151s 3s/step - loss: 0.0716 - rpn_class_loss: 2.5480e-04 - rpn_bbox_loss: 0.0041 - mrcnn_class_loss: 0.0155 - mrcnn_bbox_loss: 0.0138 - mrcnn_mask_loss: 0.0378 - val_loss: 2.1485 - val_rpn_class_loss: 0.0283 - val_rpn_bbox_loss: 1.3677 - val_mrcnn_class_loss: 0.3924 - val_mrcnn_bbox_loss: 0.2234 - val_mrcnn_mask_loss: 0.1367
# Epoch 55/100
# 50/50 [==============================] - 148s 3s/step - loss: 0.0689 - rpn_class_loss: 2.6804e-04 - rpn_bbox_loss: 0.0016 - mrcnn_class_loss: 0.0206 - mrcnn_bbox_loss: 0.0124 - mrcnn_mask_loss: 0.0341 - val_loss: 3.2897 - val_rpn_class_loss: 0.0277 - val_rpn_bbox_loss: 1.5866 - val_mrcnn_class_loss: 1.3335 - val_mrcnn_bbox_loss: 0.1864 - val_mrcnn_mask_loss: 0.1554
# Epoch 56/100
# 50/50 [==============================] - 149s 3s/step - loss: 0.0824 - rpn_class_loss: 2.8569e-04 - rpn_bbox_loss: 0.0040 - mrcnn_class_loss: 0.0347 - mrcnn_bbox_loss: 0.0139 - mrcnn_mask_loss: 0.0296 - val_loss: 3.1963 - val_rpn_class_loss: 0.0252 - val_rpn_bbox_loss: 1.5696 - val_mrcnn_class_loss: 1.2061 - val_mrcnn_bbox_loss: 0.2281 - val_mrcnn_mask_loss: 0.1673
# Epoch 57/100
# 50/50 [==============================] - 151s 3s/step - loss: 0.0492 - rpn_class_loss: 2.7357e-04 - rpn_bbox_loss: 0.0053 - mrcnn_class_loss: 0.0111 - mrcnn_bbox_loss: 0.0103 - mrcnn_mask_loss: 0.0221 - val_loss: 3.6652 - val_rpn_class_loss: 0.0272 - val_rpn_bbox_loss: 1.6070 - val_mrcnn_class_loss: 1.7273 - val_mrcnn_bbox_loss: 0.1952 - val_mrcnn_mask_loss: 0.1085
# Epoch 58/100
# 50/50 [==============================] - 149s 3s/step - loss: 0.0709 - rpn_class_loss: 2.1007e-04 - rpn_bbox_loss: 0.0057 - mrcnn_class_loss: 0.0223 - mrcnn_bbox_loss: 0.0103 - mrcnn_mask_loss: 0.0323 - val_loss: 2.8103 - val_rpn_class_loss: 0.0254 - val_rpn_bbox_loss: 1.6423 - val_mrcnn_class_loss: 0.8762 - val_mrcnn_bbox_loss: 0.1712 - val_mrcnn_mask_loss: 0.0951
# Epoch 59/100
# 50/50 [==============================] - 149s 3s/step - loss: 0.0650 - rpn_class_loss: 8.6977e-05 - rpn_bbox_loss: 0.0034 - mrcnn_class_loss: 0.0194 - mrcnn_bbox_loss: 0.0074 - mrcnn_mask_loss: 0.0348 - val_loss: 4.2320 - val_rpn_class_loss: 0.0287 - val_rpn_bbox_loss: 1.6710 - val_mrcnn_class_loss: 2.1559 - val_mrcnn_bbox_loss: 0.2842 - val_mrcnn_mask_loss: 0.0923
# Epoch 60/100
# 50/50 [==============================] - 146s 3s/step - loss: 0.0894 - rpn_class_loss: 3.0780e-04 - rpn_bbox_loss: 0.0079 - mrcnn_class_loss: 0.0293 - mrcnn_bbox_loss: 0.0168 - mrcnn_mask_loss: 0.0350 - val_loss: 3.5798 - val_rpn_class_loss: 0.0301 - val_rpn_bbox_loss: 1.6840 - val_mrcnn_class_loss: 1.5425 - val_mrcnn_bbox_loss: 0.2189 - val_mrcnn_mask_loss: 0.1042
# Epoch 61/100
# 50/50 [==============================] - 150s 3s/step - loss: 0.0831 - rpn_class_loss: 3.1627e-04 - rpn_bbox_loss: 0.0117 - mrcnn_class_loss: 0.0263 - mrcnn_bbox_loss: 0.0170 - mrcnn_mask_loss: 0.0277 - val_loss: 2.4513 - val_rpn_class_loss: 0.0315 - val_rpn_bbox_loss: 1.6550 - val_mrcnn_class_loss: 0.4812 - val_mrcnn_bbox_loss: 0.1693 - val_mrcnn_mask_loss: 0.1143
# Epoch 62/100
# 50/50 [==============================] - 148s 3s/step - loss: 0.0744 - rpn_class_loss: 3.4308e-04 - rpn_bbox_loss: 0.0160 - mrcnn_class_loss: 0.0241 - mrcnn_bbox_loss: 0.0109 - mrcnn_mask_loss: 0.0229 - val_loss: 3.0534 - val_rpn_class_loss: 0.0343 - val_rpn_bbox_loss: 1.6611 - val_mrcnn_class_loss: 1.0504 - val_mrcnn_bbox_loss: 0.2003 - val_mrcnn_mask_loss: 0.1073
# Epoch 63/100
# 50/50 [==============================] - 157s 3s/step - loss: 0.1296 - rpn_class_loss: 5.3847e-04 - rpn_bbox_loss: 0.0236 - mrcnn_class_loss: 0.0458 - mrcnn_bbox_loss: 0.0186 - mrcnn_mask_loss: 0.0410 - val_loss: 3.4815 - val_rpn_class_loss: 0.0278 - val_rpn_bbox_loss: 1.9692 - val_mrcnn_class_loss: 1.0375 - val_mrcnn_bbox_loss: 0.3293 - val_mrcnn_mask_loss: 0.1178
# Epoch 64/100
# 50/50 [==============================] - 148s 3s/step - loss: 0.0450 - rpn_class_loss: 8.0366e-05 - rpn_bbox_loss: 0.0013 - mrcnn_class_loss: 0.0058 - mrcnn_bbox_loss: 0.0061 - mrcnn_mask_loss: 0.0317 - val_loss: 3.2424 - val_rpn_class_loss: 0.0288 - val_rpn_bbox_loss: 2.0472 - val_mrcnn_class_loss: 0.7718 - val_mrcnn_bbox_loss: 0.2788 - val_mrcnn_mask_loss: 0.1157
# Epoch 65/100
# 50/50 [==============================] - 151s 3s/step - loss: 0.0495 - rpn_class_loss: 2.0193e-04 - rpn_bbox_loss: 0.0027 - mrcnn_class_loss: 0.0100 - mrcnn_bbox_loss: 0.0070 - mrcnn_mask_loss: 0.0296 - val_loss: 2.7864 - val_rpn_class_loss: 0.0306 - val_rpn_bbox_loss: 1.4680 - val_mrcnn_class_loss: 0.8729 - val_mrcnn_bbox_loss: 0.2887 - val_mrcnn_mask_loss: 0.1263
# Epoch 66/100
# 50/50 [==============================] - 155s 3s/step - loss: 0.0854 - rpn_class_loss: 3.0734e-04 - rpn_bbox_loss: 0.0277 - mrcnn_class_loss: 0.0188 - mrcnn_bbox_loss: 0.0121 - mrcnn_mask_loss: 0.0265 - val_loss: 3.2335 - val_rpn_class_loss: 0.0282 - val_rpn_bbox_loss: 1.8807 - val_mrcnn_class_loss: 0.9968 - val_mrcnn_bbox_loss: 0.2011 - val_mrcnn_mask_loss: 0.1266
# Epoch 67/100
# 50/50 [==============================] - 151s 3s/step - loss: 0.1017 - rpn_class_loss: 3.5017e-04 - rpn_bbox_loss: 0.0150 - mrcnn_class_loss: 0.0406 - mrcnn_bbox_loss: 0.0154 - mrcnn_mask_loss: 0.0303 - val_loss: 3.1819 - val_rpn_class_loss: 0.0297 - val_rpn_bbox_loss: 1.9373 - val_mrcnn_class_loss: 0.8689 - val_mrcnn_bbox_loss: 0.2036 - val_mrcnn_mask_loss: 0.1425
# Epoch 68/100
# 50/50 [==============================] - 157s 3s/step - loss: 0.0575 - rpn_class_loss: 1.3012e-04 - rpn_bbox_loss: 0.0033 - mrcnn_class_loss: 0.0143 - mrcnn_bbox_loss: 0.0064 - mrcnn_mask_loss: 0.0334 - val_loss: 2.8568 - val_rpn_class_loss: 0.0301 - val_rpn_bbox_loss: 1.9414 - val_mrcnn_class_loss: 0.4836 - val_mrcnn_bbox_loss: 0.2961 - val_mrcnn_mask_loss: 0.1056
# Epoch 69/100
# 50/50 [==============================] - 145s 3s/step - loss: 0.0476 - rpn_class_loss: 9.4769e-05 - rpn_bbox_loss: 9.8072e-04 - mrcnn_class_loss: 0.0119 - mrcnn_bbox_loss: 0.0036 - mrcnn_mask_loss: 0.0310 - val_loss: 3.3534 - val_rpn_class_loss: 0.0319 - val_rpn_bbox_loss: 2.0919 - val_mrcnn_class_loss: 0.7981 - val_mrcnn_bbox_loss: 0.3249 - val_mrcnn_mask_loss: 0.1065
# Epoch 70/100
# 50/50 [==============================] - 152s 3s/step - loss: 0.0565 - rpn_class_loss: 2.0184e-04 - rpn_bbox_loss: 0.0042 - mrcnn_class_loss: 0.0183 - mrcnn_bbox_loss: 0.0061 - mrcnn_mask_loss: 0.0277 - val_loss: 2.9129 - val_rpn_class_loss: 0.0338 - val_rpn_bbox_loss: 1.8703 - val_mrcnn_class_loss: 0.6686 - val_mrcnn_bbox_loss: 0.2372 - val_mrcnn_mask_loss: 0.1031
# Epoch 71/100
# 50/50 [==============================] - 150s 3s/step - loss: 0.0639 - rpn_class_loss: 3.1964e-04 - rpn_bbox_loss: 0.0148 - mrcnn_class_loss: 0.0141 - mrcnn_bbox_loss: 0.0120 - mrcnn_mask_loss: 0.0227 - val_loss: 3.2413 - val_rpn_class_loss: 0.0334 - val_rpn_bbox_loss: 2.0168 - val_mrcnn_class_loss: 0.6574 - val_mrcnn_bbox_loss: 0.3107 - val_mrcnn_mask_loss: 0.2231
# Epoch 72/100
# 50/50 [==============================] - 146s 3s/step - loss: 0.0664 - rpn_class_loss: 2.5178e-04 - rpn_bbox_loss: 0.0056 - mrcnn_class_loss: 0.0297 - mrcnn_bbox_loss: 0.0070 - mrcnn_mask_loss: 0.0238 - val_loss: 3.1094 - val_rpn_class_loss: 0.0311 - val_rpn_bbox_loss: 1.9832 - val_mrcnn_class_loss: 0.6927 - val_mrcnn_bbox_loss: 0.2889 - val_mrcnn_mask_loss: 0.1135
# Epoch 73/100
# 50/50 [==============================] - 152s 3s/step - loss: 0.0757 - rpn_class_loss: 2.9896e-04 - rpn_bbox_loss: 0.0086 - mrcnn_class_loss: 0.0170 - mrcnn_bbox_loss: 0.0129 - mrcnn_mask_loss: 0.0369 - val_loss: 3.2685 - val_rpn_class_loss: 0.0359 - val_rpn_bbox_loss: 2.3052 - val_mrcnn_class_loss: 0.5733 - val_mrcnn_bbox_loss: 0.2479 - val_mrcnn_mask_loss: 0.1063
# Epoch 74/100
# 50/50 [==============================] - 147s 3s/step - loss: 0.0409 - rpn_class_loss: 1.1254e-04 - rpn_bbox_loss: 0.0017 - mrcnn_class_loss: 0.0031 - mrcnn_bbox_loss: 0.0069 - mrcnn_mask_loss: 0.0291 - val_loss: 3.4780 - val_rpn_class_loss: 0.0361 - val_rpn_bbox_loss: 2.3234 - val_mrcnn_class_loss: 0.7540 - val_mrcnn_bbox_loss: 0.2708 - val_mrcnn_mask_loss: 0.0937
# Epoch 75/100
# 50/50 [==============================] - 153s 3s/step - loss: 0.0493 - rpn_class_loss: 1.9548e-04 - rpn_bbox_loss: 0.0040 - mrcnn_class_loss: 0.0100 - mrcnn_bbox_loss: 0.0101 - mrcnn_mask_loss: 0.0250 - val_loss: 3.1988 - val_rpn_class_loss: 0.0359 - val_rpn_bbox_loss: 2.2303 - val_mrcnn_class_loss: 0.6896 - val_mrcnn_bbox_loss: 0.1406 - val_mrcnn_mask_loss: 0.1025
# Epoch 76/100
# 50/50 [==============================] - 151s 3s/step - loss: 0.0461 - rpn_class_loss: 3.6276e-04 - rpn_bbox_loss: 0.0031 - mrcnn_class_loss: 0.0156 - mrcnn_bbox_loss: 0.0051 - mrcnn_mask_loss: 0.0219 - val_loss: 3.2119 - val_rpn_class_loss: 0.0340 - val_rpn_bbox_loss: 2.0878 - val_mrcnn_class_loss: 0.7561 - val_mrcnn_bbox_loss: 0.2329 - val_mrcnn_mask_loss: 0.1010
# Epoch 77/100
# 50/50 [==============================] - 144s 3s/step - loss: 0.0579 - rpn_class_loss: 3.7942e-04 - rpn_bbox_loss: 0.0029 - mrcnn_class_loss: 0.0227 - mrcnn_bbox_loss: 0.0055 - mrcnn_mask_loss: 0.0264 - val_loss: 3.1543 - val_rpn_class_loss: 0.0341 - val_rpn_bbox_loss: 2.0414 - val_mrcnn_class_loss: 0.6748 - val_mrcnn_bbox_loss: 0.3036 - val_mrcnn_mask_loss: 0.1004
# Epoch 78/100
# 50/50 [==============================] - 153s 3s/step - loss: 0.0622 - rpn_class_loss: 3.4686e-04 - rpn_bbox_loss: 0.0026 - mrcnn_class_loss: 0.0167 - mrcnn_bbox_loss: 0.0078 - mrcnn_mask_loss: 0.0347 - val_loss: 3.2650 - val_rpn_class_loss: 0.0328 - val_rpn_bbox_loss: 2.0765 - val_mrcnn_class_loss: 0.8074 - val_mrcnn_bbox_loss: 0.2117 - val_mrcnn_mask_loss: 0.1366
# Epoch 79/100
# 50/50 [==============================] - 149s 3s/step - loss: 0.0417 - rpn_class_loss: 9.8364e-05 - rpn_bbox_loss: 9.4348e-04 - mrcnn_class_loss: 0.0075 - mrcnn_bbox_loss: 0.0043 - mrcnn_mask_loss: 0.0289 - val_loss: 3.2843 - val_rpn_class_loss: 0.0316 - val_rpn_bbox_loss: 1.9649 - val_mrcnn_class_loss: 0.9282 - val_mrcnn_bbox_loss: 0.2384 - val_mrcnn_mask_loss: 0.1212
# Epoch 80/100
# 50/50 [==============================] - 150s 3s/step - loss: 0.0441 - rpn_class_loss: 1.6573e-04 - rpn_bbox_loss: 0.0015 - mrcnn_class_loss: 0.0139 - mrcnn_bbox_loss: 0.0048 - mrcnn_mask_loss: 0.0237 - val_loss: 3.6493 - val_rpn_class_loss: 0.0311 - val_rpn_bbox_loss: 1.9936 - val_mrcnn_class_loss: 1.2971 - val_mrcnn_bbox_loss: 0.1863 - val_mrcnn_mask_loss: 0.1413
# Epoch 81/100
# 50/50 [==============================] - 152s 3s/step - loss: 0.0375 - rpn_class_loss: 2.0088e-04 - rpn_bbox_loss: 0.0015 - mrcnn_class_loss: 0.0126 - mrcnn_bbox_loss: 0.0033 - mrcnn_mask_loss: 0.0200 - val_loss: 3.2028 - val_rpn_class_loss: 0.0303 - val_rpn_bbox_loss: 1.9535 - val_mrcnn_class_loss: 0.8936 - val_mrcnn_bbox_loss: 0.1979 - val_mrcnn_mask_loss: 0.1275
# Epoch 82/100
# 50/50 [==============================] - 150s 3s/step - loss: 0.0515 - rpn_class_loss: 2.8795e-04 - rpn_bbox_loss: 0.0013 - mrcnn_class_loss: 0.0183 - mrcnn_bbox_loss: 0.0042 - mrcnn_mask_loss: 0.0274 - val_loss: 3.2580 - val_rpn_class_loss: 0.0296 - val_rpn_bbox_loss: 1.9413 - val_mrcnn_class_loss: 1.0284 - val_mrcnn_bbox_loss: 0.1536 - val_mrcnn_mask_loss: 0.1051
# Epoch 83/100
# 50/50 [==============================] - 150s 3s/step - loss: 0.0455 - rpn_class_loss: 9.1764e-05 - rpn_bbox_loss: 0.0011 - mrcnn_class_loss: 0.0098 - mrcnn_bbox_loss: 0.0041 - mrcnn_mask_loss: 0.0304 - val_loss: 2.8133 - val_rpn_class_loss: 0.0303 - val_rpn_bbox_loss: 1.8807 - val_mrcnn_class_loss: 0.5586 - val_mrcnn_bbox_loss: 0.2294 - val_mrcnn_mask_loss: 0.1143
# Epoch 84/100
# 50/50 [==============================] - 138s 3s/step - loss: 0.0734 - rpn_class_loss: 1.1129e-04 - rpn_bbox_loss: 0.0016 - mrcnn_class_loss: 0.0369 - mrcnn_bbox_loss: 0.0062 - mrcnn_mask_loss: 0.0286 - val_loss: 2.9322 - val_rpn_class_loss: 0.0288 - val_rpn_bbox_loss: 1.9367 - val_mrcnn_class_loss: 0.6260 - val_mrcnn_bbox_loss: 0.2364 - val_mrcnn_mask_loss: 0.1044
# Epoch 85/100
# 50/50 [==============================] - 140s 3s/step - loss: 0.0390 - rpn_class_loss: 1.6247e-04 - rpn_bbox_loss: 0.0023 - mrcnn_class_loss: 0.0088 - mrcnn_bbox_loss: 0.0047 - mrcnn_mask_loss: 0.0230 - val_loss: 3.2136 - val_rpn_class_loss: 0.0293 - val_rpn_bbox_loss: 1.9564 - val_mrcnn_class_loss: 0.9025 - val_mrcnn_bbox_loss: 0.2282 - val_mrcnn_mask_loss: 0.0972
# Epoch 86/100
# 50/50 [==============================] - 147s 3s/step - loss: 0.0366 - rpn_class_loss: 1.5863e-04 - rpn_bbox_loss: 0.0024 - mrcnn_class_loss: 0.0101 - mrcnn_bbox_loss: 0.0037 - mrcnn_mask_loss: 0.0201 - val_loss: 3.5927 - val_rpn_class_loss: 0.0289 - val_rpn_bbox_loss: 1.9234 - val_mrcnn_class_loss: 1.1782 - val_mrcnn_bbox_loss: 0.3489 - val_mrcnn_mask_loss: 0.1133
# Epoch 87/100
# 50/50 [==============================] - 152s 3s/step - loss: 0.0551 - rpn_class_loss: 1.9078e-04 - rpn_bbox_loss: 0.0023 - mrcnn_class_loss: 0.0153 - mrcnn_bbox_loss: 0.0073 - mrcnn_mask_loss: 0.0299 - val_loss: 3.5632 - val_rpn_class_loss: 0.0285 - val_rpn_bbox_loss: 2.0519 - val_mrcnn_class_loss: 1.0797 - val_mrcnn_bbox_loss: 0.2173 - val_mrcnn_mask_loss: 0.1857
# Epoch 88/100
# 50/50 [==============================] - 152s 3s/step - loss: 0.0540 - rpn_class_loss: 1.6582e-04 - rpn_bbox_loss: 0.0018 - mrcnn_class_loss: 0.0059 - mrcnn_bbox_loss: 0.0087 - mrcnn_mask_loss: 0.0375 - val_loss: 4.2088 - val_rpn_class_loss: 0.0254 - val_rpn_bbox_loss: 1.8395 - val_mrcnn_class_loss: 1.8835 - val_mrcnn_bbox_loss: 0.2970 - val_mrcnn_mask_loss: 0.1634
# Epoch 89/100
# 50/50 [==============================] - 150s 3s/step - loss: 0.0530 - rpn_class_loss: 1.1182e-04 - rpn_bbox_loss: 0.0018 - mrcnn_class_loss: 0.0115 - mrcnn_bbox_loss: 0.0093 - mrcnn_mask_loss: 0.0303 - val_loss: 2.9883 - val_rpn_class_loss: 0.0288 - val_rpn_bbox_loss: 2.0185 - val_mrcnn_class_loss: 0.5225 - val_mrcnn_bbox_loss: 0.3159 - val_mrcnn_mask_loss: 0.1026
# Epoch 90/100
# 50/50 [==============================] - 153s 3s/step - loss: 0.0369 - rpn_class_loss: 1.4303e-04 - rpn_bbox_loss: 0.0078 - mrcnn_class_loss: 0.0040 - mrcnn_bbox_loss: 0.0029 - mrcnn_mask_loss: 0.0220 - val_loss: 3.6749 - val_rpn_class_loss: 0.0297 - val_rpn_bbox_loss: 1.9959 - val_mrcnn_class_loss: 1.1711 - val_mrcnn_bbox_loss: 0.3724 - val_mrcnn_mask_loss: 0.1059
# Epoch 91/100
# 50/50 [==============================] - 153s 3s/step - loss: 0.0323 - rpn_class_loss: 1.6298e-04 - rpn_bbox_loss: 0.0019 - mrcnn_class_loss: 0.0078 - mrcnn_bbox_loss: 0.0032 - mrcnn_mask_loss: 0.0193 - val_loss: 3.3485 - val_rpn_class_loss: 0.0291 - val_rpn_bbox_loss: 1.9304 - val_mrcnn_class_loss: 1.0437 - val_mrcnn_bbox_loss: 0.2559 - val_mrcnn_mask_loss: 0.0894
# Epoch 92/100
# 50/50 [==============================] - 160s 3s/step - loss: 0.0867 - rpn_class_loss: 1.3177e-04 - rpn_bbox_loss: 0.0034 - mrcnn_class_loss: 0.0340 - mrcnn_bbox_loss: 0.0086 - mrcnn_mask_loss: 0.0406 - val_loss: 3.6438 - val_rpn_class_loss: 0.0291 - val_rpn_bbox_loss: 1.9122 - val_mrcnn_class_loss: 1.2443 - val_mrcnn_bbox_loss: 0.2792 - val_mrcnn_mask_loss: 0.1790
# Epoch 93/100
# 50/50 [==============================] - 142s 3s/step - loss: 0.0411 - rpn_class_loss: 6.0627e-05 - rpn_bbox_loss: 0.0025 - mrcnn_class_loss: 0.0037 - mrcnn_bbox_loss: 0.0040 - mrcnn_mask_loss: 0.0309 - val_loss: 4.0410 - val_rpn_class_loss: 0.0282 - val_rpn_bbox_loss: 1.8949 - val_mrcnn_class_loss: 1.8083 - val_mrcnn_bbox_loss: 0.2038 - val_mrcnn_mask_loss: 0.1059
# Epoch 94/100
# 50/50 [==============================] - 148s 3s/step - loss: 0.0332 - rpn_class_loss: 1.2400e-04 - rpn_bbox_loss: 0.0024 - mrcnn_class_loss: 0.0017 - mrcnn_bbox_loss: 0.0039 - mrcnn_mask_loss: 0.0251 - val_loss: 4.3216 - val_rpn_class_loss: 0.0283 - val_rpn_bbox_loss: 1.9767 - val_mrcnn_class_loss: 1.9826 - val_mrcnn_bbox_loss: 0.2397 - val_mrcnn_mask_loss: 0.0942
# Epoch 95/100
# 50/50 [==============================] - 147s 3s/step - loss: 0.0391 - rpn_class_loss: 1.3923e-04 - rpn_bbox_loss: 0.0020 - mrcnn_class_loss: 0.0124 - mrcnn_bbox_loss: 0.0029 - mrcnn_mask_loss: 0.0216 - val_loss: 3.2368 - val_rpn_class_loss: 0.0259 - val_rpn_bbox_loss: 1.8865 - val_mrcnn_class_loss: 0.9944 - val_mrcnn_bbox_loss: 0.2414 - val_mrcnn_mask_loss: 0.0886
# Epoch 96/100
# 50/50 [==============================] - 148s 3s/step - loss: 0.0568 - rpn_class_loss: 1.3435e-04 - rpn_bbox_loss: 0.0041 - mrcnn_class_loss: 0.0239 - mrcnn_bbox_loss: 0.0076 - mrcnn_mask_loss: 0.0211 - val_loss: 3.5241 - val_rpn_class_loss: 0.0280 - val_rpn_bbox_loss: 1.9171 - val_mrcnn_class_loss: 1.2271 - val_mrcnn_bbox_loss: 0.2473 - val_mrcnn_mask_loss: 0.1046
# Epoch 97/100
# 50/50 [==============================] - 158s 3s/step - loss: 0.0657 - rpn_class_loss: 1.9600e-04 - rpn_bbox_loss: 0.0042 - mrcnn_class_loss: 0.0244 - mrcnn_bbox_loss: 0.0057 - mrcnn_mask_loss: 0.0312 - val_loss: 3.9963 - val_rpn_class_loss: 0.0296 - val_rpn_bbox_loss: 2.0332 - val_mrcnn_class_loss: 1.5049 - val_mrcnn_bbox_loss: 0.2338 - val_mrcnn_mask_loss: 0.1948
# Epoch 98/100
# 50/50 [==============================] - 144s 3s/step - loss: 0.0300 - rpn_class_loss: 6.2266e-05 - rpn_bbox_loss: 3.6878e-04 - mrcnn_class_loss: 0.0019 - mrcnn_bbox_loss: 7.3189e-04 - mrcnn_mask_loss: 0.0269 - val_loss: 3.8487 - val_rpn_class_loss: 0.0303 - val_rpn_bbox_loss: 2.0587 - val_mrcnn_class_loss: 1.3426 - val_mrcnn_bbox_loss: 0.2582 - val_mrcnn_mask_loss: 0.1589
# Epoch 99/100
# 50/50 [==============================] - 151s 3s/step - loss: 0.0289 - rpn_class_loss: 1.3895e-04 - rpn_bbox_loss: 0.0012 - mrcnn_class_loss: 4.3653e-04 - mrcnn_bbox_loss: 0.0024 - mrcnn_mask_loss: 0.0247 - val_loss: 3.8415 - val_rpn_class_loss: 0.0296 - val_rpn_bbox_loss: 2.0605 - val_mrcnn_class_loss: 1.4406 - val_mrcnn_bbox_loss: 0.2290 - val_mrcnn_mask_loss: 0.0817
# Epoch 100/100
# 50/50 [==============================] - 154s 3s/step - loss: 0.0338 - rpn_class_loss: 1.3245e-04 - rpn_bbox_loss: 0.0011 - mrcnn_class_loss: 0.0100 - mrcnn_bbox_loss: 0.0029 - mrcnn_mask_loss: 0.0197 - val_loss: 3.7175 - val_rpn_class_loss: 0.0303 - val_rpn_bbox_loss: 2.1053 - val_mrcnn_class_loss: 1.2475 - val_mrcnn_bbox_loss: 0.2366 - val_mrcnn_mask_loss: 0.0977
# Training took 247.38 minutes

# %%
# Fine tune all layers
# Passing layers="all" trains all layers. You can also 
# pass a regular expression to select which layers to
# train by name pattern.
start_train = time.time()
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE / 10,
            epochs=100, 
            layers="all")
end_train = time.time()
minutes = round((end_train - start_train) / 60, 2)
print(f'Training took {minutes} minutes')
# Out:
# Starting at epoch 100. LR=0.0001
#
# Checkpoint Path: ../../aktwelve_mask_rcnn/g_logs/gomi20210415T1644/mask_rcnn_gomi_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res4g_branch2a         (Conv2D)
# bn4g_branch2a          (BatchNorm)
# res4g_branch2b         (Conv2D)
# bn4g_branch2b          (BatchNorm)
# res4g_branch2c         (Conv2D)
# bn4g_branch2c          (BatchNorm)
# res4h_branch2a         (Conv2D)
# bn4h_branch2a          (BatchNorm)
# res4h_branch2b         (Conv2D)
# bn4h_branch2b          (BatchNorm)
# res4h_branch2c         (Conv2D)
# bn4h_branch2c          (BatchNorm)
# res4i_branch2a         (Conv2D)
# bn4i_branch2a          (BatchNorm)
# res4i_branch2b         (Conv2D)
# bn4i_branch2b          (BatchNorm)
# res4i_branch2c         (Conv2D)
# bn4i_branch2c          (BatchNorm)
# res4j_branch2a         (Conv2D)
# bn4j_branch2a          (BatchNorm)
# res4j_branch2b         (Conv2D)
# bn4j_branch2b          (BatchNorm)
# res4j_branch2c         (Conv2D)
# bn4j_branch2c          (BatchNorm)
# res4k_branch2a         (Conv2D)
# bn4k_branch2a          (BatchNorm)
# res4k_branch2b         (Conv2D)
# bn4k_branch2b          (BatchNorm)
# res4k_branch2c         (Conv2D)
# bn4k_branch2c          (BatchNorm)
# res4l_branch2a         (Conv2D)
# bn4l_branch2a          (BatchNorm)
# res4l_branch2b         (Conv2D)
# bn4l_branch2b          (BatchNorm)
# res4l_branch2c         (Conv2D)
# bn4l_branch2c          (BatchNorm)
# res4m_branch2a         (Conv2D)
# bn4m_branch2a          (BatchNorm)
# res4m_branch2b         (Conv2D)
# bn4m_branch2b          (BatchNorm)
# res4m_branch2c         (Conv2D)
# bn4m_branch2c          (BatchNorm)
# res4n_branch2a         (Conv2D)
# bn4n_branch2a          (BatchNorm)
# res4n_branch2b         (Conv2D)
# bn4n_branch2b          (BatchNorm)
# res4n_branch2c         (Conv2D)
# bn4n_branch2c          (BatchNorm)
# res4o_branch2a         (Conv2D)
# bn4o_branch2a          (BatchNorm)
# res4o_branch2b         (Conv2D)
# bn4o_branch2b          (BatchNorm)
# res4o_branch2c         (Conv2D)
# bn4o_branch2c          (BatchNorm)
# res4p_branch2a         (Conv2D)
# bn4p_branch2a          (BatchNorm)
# res4p_branch2b         (Conv2D)
# bn4p_branch2b          (BatchNorm)
# res4p_branch2c         (Conv2D)
# bn4p_branch2c          (BatchNorm)
# res4q_branch2a         (Conv2D)
# bn4q_branch2a          (BatchNorm)
# res4q_branch2b         (Conv2D)
# bn4q_branch2b          (BatchNorm)
# res4q_branch2c         (Conv2D)
# bn4q_branch2c          (BatchNorm)
# res4r_branch2a         (Conv2D)
# bn4r_branch2a          (BatchNorm)
# res4r_branch2b         (Conv2D)
# bn4r_branch2b          (BatchNorm)
# res4r_branch2c         (Conv2D)
# bn4r_branch2c          (BatchNorm)
# res4s_branch2a         (Conv2D)
# bn4s_branch2a          (BatchNorm)
# res4s_branch2b         (Conv2D)
# bn4s_branch2b          (BatchNorm)
# res4s_branch2c         (Conv2D)
# bn4s_branch2c          (BatchNorm)
# res4t_branch2a         (Conv2D)
# bn4t_branch2a          (BatchNorm)
# res4t_branch2b         (Conv2D)
# bn4t_branch2b          (BatchNorm)
# res4t_branch2c         (Conv2D)
# bn4t_branch2c          (BatchNorm)
# res4u_branch2a         (Conv2D)
# bn4u_branch2a          (BatchNorm)
# res4u_branch2b         (Conv2D)
# bn4u_branch2b          (BatchNorm)
# res4u_branch2c         (Conv2D)
# bn4u_branch2c          (BatchNorm)
# res4v_branch2a         (Conv2D)
# bn4v_branch2a          (BatchNorm)
# res4v_branch2b         (Conv2D)
# bn4v_branch2b          (BatchNorm)
# res4v_branch2c         (Conv2D)
# bn4v_branch2c          (BatchNorm)
# res4w_branch2a         (Conv2D)
# bn4w_branch2a          (BatchNorm)
# res4w_branch2b         (Conv2D)
# bn4w_branch2b          (BatchNorm)
# res4w_branch2c         (Conv2D)
# bn4w_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# anchors                (ConstLayer)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layers with arguments in `__init__` must override `get_config`.
# Training took 2.44 minutes

# %% [markdown]
# # Prepare to run Inference
# Create a new InferenceConfig, then use it to create a new model.

# %%
class InferenceConfig(GomiConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1
    IMAGE_MIN_DIM = 512
    IMAGE_MAX_DIM = 512
    DETECTION_MIN_CONFIDENCE = 0.85
    

inference_config = InferenceConfig()

# %%
# Recreate the model in inference mode
model = modellib.MaskRCNN(mode="inference", 
                          config=inference_config,
                          model_dir=MODEL_DIR)

# %%
# Get path to saved weights
# Either set a specific path or find last trained weights
# model_path = os.path.join(ROOT_DIR, ".h5 file name here")
model_path = model.find_last()

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  ../../aktwelve_mask_rcnn/g_logs/gomi20210415T1644/mask_rcnn_gomi_0100.h5
# Re-starting from epoch 100

# %% [markdown]
# # Run Inference
# Run model.detect() on real images.
#
# We get some false positives, and some misses. More training images are likely needed to improve the results.

# %%
import skimage
real_test_dir = '../datasets/garbage/real_test/images'
image_paths = []
for filename in os.listdir(real_test_dir):
    if os.path.splitext(filename)[1].lower() in ['.png', '.jpg', '.jpeg']:
        image_paths.append(os.path.join(real_test_dir, filename))

for image_path in image_paths:
    img = skimage.io.imread(image_path)
    img_arr = np.array(img)
    results = model.detect([img_arr], verbose=1)
    r = results[0]
    visualize.display_instances(img, r['rois'], r['masks'], r['class_ids'], 
                                dataset_val.class_names, r['scores'], figsize=(5,5))
# Out:
# Processing 1 images
# image                    shape: (512, 384, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 20)               min:    0.00000  max:  512.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (384, 512, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 20)               min:    0.00000  max:  512.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (384, 512, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 20)               min:    0.00000  max:  512.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (384, 512, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 20)               min:    0.00000  max:  512.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (384, 512, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  135.10000  float64
# image_metas              shape: (1, 20)               min:    0.00000  max:  512.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (384, 512, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 20)               min:    0.00000  max:  512.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (512, 384, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 20)               min:    0.00000  max:  512.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (384, 512, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  139.10000  float64
# image_metas              shape: (1, 20)               min:    0.00000  max:  512.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
#
# *** No instances to display ***

# %% [markdown]
# # Validation Method
# - 推論のゴミ位置と教師データのゴミ位置が一致している画像の平均IoU
# - 未検出数（教師データのゴミ位置が全く検出されていない画像の枚数）
# - 誤検出数（推論のゴミ位置が教師データと全くかぶっていない画像の枚数）
# - Recall (上記の未検出数 / ゴミがある画像)
# - Precision (上記の誤検出数 / ゴミがある画像)
#
# を求めました。
#
# この評価検証方法にした理由はゴミの有無を特定することを最優先したからです。
#
# なので評価で欲しい数値の優先順位が上位から
# - 未検出数
# - 誤検出数
# - IoU
# となりました。
# 脳腫瘍部分を検出できたかどうか、どれくらい間違えて検出してしまったかを優先し、どれくらい領域が正確に検出できたかどうかは評価としてはあったほうがいいので脳腫瘍が検出できた画像のみで評価しました。
